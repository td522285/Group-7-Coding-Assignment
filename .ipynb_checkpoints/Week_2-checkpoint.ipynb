# %% [markdown]
# # Week 2 Meeting Ideas
#
# # Faber-Jackson Relation
# Read into the 'fundamental plane' of elliptical galaxies - Effective Radius and Effective brightness can be used to calculate Luminosity, which is tightly correlated to velocity dispersion.
#
# We need to combine stellar mass, stellar kinematic and morphological data to find a sample.
# Once we obtain a sample, we'll need to find L vs v_spread.
# Plotted on a log scale and compare the fits with those of different.
#
# Biggest problem may be finding a good galaxy sample.
# Good quality samples will include a range of other parameters to show that these do not affect the F-J Relation.
#
# # Sources
# https://www.aoc.nrao.edu/~smyers/courses/astro12/tully.html On the Tully-Fisher and Faber-Jackson Relations
# https://ui.adsabs.harvard.edu/abs/1976ApJ...204..668F/abstract
#
# The data sheets they gave us.
# https://docs.datacentral.org.au/sami/ SAMI GALACTIC SURVEY
#
# # Considerations
# What 'light' are we measuring (bolometric)?
#
# # TODO:
# Have a rough sketch of all the galaxies.
